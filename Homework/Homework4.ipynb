# %% [markdown]
# Homework 4

# %%
import pandas as pd

anscombe_df = pd.read_json('/content/sample_data/anscombe.json')
anscombe_df.head()
# Out:
#   Series   X     Y
# 0      I  10  8.04
# 1      I   8  6.95
# 2      I  13  7.58
# 3      I   9  8.81
# 4      I  11  8.33

# %% [markdown]
# 2.)

# %%
grouped_df = anscombe_df.groupby('Series')
grouped_df.describe()
# Out:
#            X                                               Y            \
#        count mean       std  min  25%  50%   75%   max count      mean
# Series
# I       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# II      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III     11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV      11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#              std   min    25%   50%   75%    max
# Series
# I       2.032890  4.26  6.315  7.58  8.57  10.84
# II      2.031657  3.10  6.695  8.14  8.95   9.26
# III     2.030424  5.39  6.250  7.11  7.98  12.74
# IV      2.030579  5.25  6.170  7.04  8.19  12.50

# %% [markdown]
# 3.)

# %%
grouped_df.boxplot()
grouped_df.plot(x="X",y="Y",kind="scatter")
# Out:
# Series
# I      Axes(0.125,0.11;0.775x0.77)
# II     Axes(0.125,0.11;0.775x0.77)
# III    Axes(0.125,0.11;0.775x0.77)
# IV     Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# 4.) From the box plot graphs, we can see the distributions of the X and Y variables in each of the datasets and compare them. We can see how the IV dataset is composed of a mostly a single X value with one outlier, with the paired Y values varying only slightly from that value. In general, we can see that the median Y value is less than the median X value across all the datasets. Additionally, we can see that the range of X in the first 3 datasets (I,II,III) are approximately the same. This is further validated by the descibe method used in part 2. On the contrary, we can see the range of the Y values in the first 3 sets seems to be getting smaller, while the median stays approximately the same.
#
# From the scatter plots we can see what the relationships between the X and Y variables are in each of the datasets. In the I dataset, we can see that it a roughly positive relationship (as X increases, Y increases), but isn't very strong as there is a lot of variability. We can say that it is roughly linear. On the contrary, both the II and III datasets have much clearer relationships, with II having a quadratic relationship between X and Y and III having a positive linear relationship between X and Y. However, notice that dataset III has a very noticable outlier where dataset II doesn't. Finally, dataset IV is a vertical line with one outlier off the line.
